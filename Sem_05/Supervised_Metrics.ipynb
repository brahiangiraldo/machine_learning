# %% [markdown]
# # Clasification

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import make_classification

# import classifiers
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as kNN

# Import validation
from sklearn.model_selection import train_test_split

# %%
# we create 100 separable points
X, y = make_classification(n_samples = 1000, n_features=2, n_classes = 3, n_redundant=0, n_informative=2, n_clusters_per_class=1, random_state=6)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
# Plot train / test data
print(X.shape, y.shape)
print(X.shape, y.shape, X_train.shape, y_train.shape, X_test.shape, y_test.shape)

_, axes= plt.subplots(1, 2, figsize=(8, 4))
axes[0].scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='Blues', s=50, alpha=0.6)
axes[1].scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap='Blues', s=50, alpha=0.6)
axes[1].scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='Blues', s=50, alpha=0.6)
# Out:
# (1000, 2) (1000,)
# (1000, 2) (1000,) (800, 2) (800,) (200, 2) (200,)

# %%
'''
    --> Paste your plot_2d_decision_boundaries function here!
'''

# %%
models = [ LogisticRegression() , KNN(__neighbors) , _ ]

_, axes = plt.subplots(1,3, figsize = (20,5))
preds = {} 

# fit the models
for _ in _ :
    #
    clf = _
    clf.fit( _ , _ )
    
    # Plot everything
    
plt.show()

# %% [markdown]
# ## Metricas de desempeño
#
# Módulo de [Metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) de sklearn

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
_, axes = plt.subplots(1, _ , figsize = (21,4))

# Compute metrics - plot confusion matrix
for _ in _ :
  print ("########----- Results for {0} -----########".format( _ ))
  accuracy = accuracy_score( _ , _ )
  precision = precision_score( _ , _ , average = "micro")
  recall = recall_score( _ , _ , average = "micro")
  f1 = f1_score( _ , _ , average = "micro")
  cm = confusion_matrix( _ , _ )
  ##--------------
  print("-- Acc --\t -- Prec --\t -- Rec --\t -- F1 --  ")
  print("  {0:.3f}  \t   {1:.3f}  \t   {2:.3f}  \t   {3:.3f}  \t".format(accuracy, precision, recall, f1))
  sns.heatmap(cm, cmap = "hot", annot = True, ax = _ )
  axes[i].set_title( _ )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 _, axes = plt.subplots(1, _ , figsize = (21,4))
#       3 # Compute metrics - plot confusion matrix
#       4 for _ in _ :
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## En datos reales

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import load_digits

# import classifiers
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as kNN

# %%
digits = load_digits()
print(digits.data.shape)

plt.imshow(digits.images[0].reshape(8,8), cmap="gray")
# Out:
# (1797, 64)

# %% [markdown]
# Evalúe los distintos algoritmos entrenando con esta base de datos.

# %% [markdown]
# # Regression

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import make_regression

# import classifiers
from sklearn.linear_model import LinearRegression

# Import validation
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples = 1000, n_features = 1 , noise = 0.1 , random_state = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)


np.random.seed(0)
y_test = y_test + np.random.normal(len(y_test)) * 0.1


print(X.shape, y.shape, X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Plot train / test data
_,ax = plt.subplots(1,2, figsize=(8,4))
ax[0].scatter(X,y, edgecolor= 'k', c='g') 
ax[1].scatter(X_train,y_train, edgecolor= 'k', c='g') 
ax[1].scatter(X_test,y_test, edgecolor= 'k', c='g')
# Out:
# (1000, 1) (1000,) (800, 1) (800,) (200, 1) (200,)

# %%
# Train a linear regression

# %% [markdown]
# ## Metricas de desempeño
#
# Módulo de [Metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) de sklearn

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create an instance of LinearRegression
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Use the fitted model to make predictions on the test data
predictions = model.predict(X_test)

mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)

print('MAE: {0}'.format(mae))
print('MSE: {0}'.format(mse))
# Out:
# MAE: 20.176726817798013
# MSE: 407.11079888979936
